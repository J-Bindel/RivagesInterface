# %% [markdown]
# ## Hydrogeological models ![RIVAGES_logo2.jpg](attachment:647a182c-854d-4a05-8e63-df6c002f312f.jpg)

# %%
import interface
carte, text_selector, site_selector,modele_selector, calendar_start, calendar_end, slider, scenario_selector, button = interface.affichage_carte()
carte
# Out:
# folder_path :  /DATA/These/Projects/RivagesInterface/simulation/
# folder + string :  /DATA/These/Projects/RivagesInterface/simulation/data/study_sites.txt
# GridspecLayout(children=(Map(center=[49, -1], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom…
