# %%
import pp_RTD as rtd
import importlib

# %%
modelfolder = ["H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.002_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.002_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.002_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.001_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.001_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.001_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.0005_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.0005_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.0005_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.004_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.004_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.004_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.006_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.006_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.006_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.008_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.008_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.008_geo_0_thick_10_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.01_geo_0_thick_100_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.01_geo_0_thick_50_K_0.864_Sy_0.01",
               "H:/Users/gauvain/DEM/Breville-Sur-Mer/model_time_0.01_geo_0_thick_10_K_0.864_Sy_0.01",]

# %%
importlib.reload(rtd)
rtd.export_DEM_watertable(modelfolder)
#rtd.create_files(modelfolder)

# %%
importlib.reload(rtd)
rtd.display(modelfolder)
